# %%
# !apt-get install -y fonts-nanum > /dev/null
# !fc-cache -fv > /dev/null
# !rm -rf ~/.cache/matplotlib > /dev/null
# 런타임 다시시작
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %%
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# # Seaborn 데이터 시각화

# %%
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터

# %% [markdown]
# ### 1. 카운트 플롯

# %%
sns.countplot(x='class', data=titanic)
plt.title('타이타닉호의 각 클래스별 승객수')
plt.show()

# %%
sns.countplot(x="day", data=tips)
plt.title("요일별 팁을 준 횟수")
plt.show()

# %% [markdown]
# ## 2. 다차원 실수형 데이터
#
# - .pairplot()

# %%
sns.pairplot(iris)
plt.show()

# %%
sns.pairplot(iris, hue='species', markers=['o','s','D']);

# %% [markdown]
# ### 3. 2차원 카테고리 데이터
# - heatmap()

# %%
tt = titanic.pivot_table(index='class', columns='sex', aggfunc='size')
tt
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(tt, annot=True, fmt="d")
plt.title("Titanic호의 선실별 남녀 승객수")
plt.show()

# %%
sns.heatmap(tt, cmap=sns.light_palette("navy", as_cmap=True), annot=True, fmt="d")
plt.title("Titanic호의 선실별 남녀 승객수")
plt.show()

# %%
flights_passengers = flights.pivot("month", "year", "passengers")
plt.figure(figsize=(12,10))
plt.title("연도, 월 별 승객수에 대한 Heatmap")
sns.heatmap(flights_passengers, cmap=sns.light_palette("green", as_cmap=True), annot=True, fmt="d", linewidths=1)
plt.show()

# %% [markdown]
# ## 4. 다차원 복합 데이터
# - barplot()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="day", y="total_bill", data=tips)
plt.title("요일 별 전체 요금의 평균")
plt.show()

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
plt.title("요일 별, 성별 전체 요금의 평균")
plt.show()

# %% [markdown]
# - boxplot()

# %%
sns.boxplot(x="day", y="total_bill", data=tips)
plt.title("요일 별 전체 팁의 Box Plot")
plt.show()

# %%
sns.boxplot(x="day", y="total_bill", hue='sex', data=tips)
plt.title("요일 별/성별 전체 팁의 Box Plot")
plt.show()
