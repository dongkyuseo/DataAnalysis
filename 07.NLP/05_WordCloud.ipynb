# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %% [markdown]
# ## 1. Alice in Wonderland

# %%
from google.colab import files
uploaded = files.upload()
textfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-349cb2a1-c030-4b70-b6c7-7cae039d6b99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-349cb2a1-c030-4b70-b6c7-7cae039d6b99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alice.txt to Alice.txt

# %%
from google.colab import files
uploaded = files.upload()
maskfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-9330e047-974a-426e-844c-359ae6ea64ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9330e047-974a-426e-844c-359ae6ea64ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Alice_mask.png to Alice_mask.png

# %%
with open(textfile) as fp:
  text = fp.read()

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
stop_words.add('said')

# %%
wc = WordCloud(background_color='white', 
               max_words = 1000,
               stopwords=stop_words)
wc.generate(text)

# %%
type(wc.words_)
# Out:
# dict

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
  print(keys[i], ':', values[i])
# Out:
# Alice : 1.0
# little : 0.2958904109589041
# one : 0.2602739726027397
# know : 0.2465753424657534
# like : 0.2356164383561644
# would : 0.2273972602739726
# went : 0.2273972602739726
# thing : 0.2191780821917808
# could : 0.21095890410958903
# time : 0.21095890410958903

# %%
plt.figure(figsize=(10,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# - 그림 위에 표시하기

# %%
mask = np.array(Image.open(maskfile))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', 
               mask=mask,
               max_words = 1000,
               stopwords=stop_words)
wc.generate(text)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 2. Star Wars

# %%
from google.colab import files
uploaded = files.upload()
textfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-b5f91b11-6a8b-4086-bc81-131c2b350843" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b5f91b11-6a8b-4086-bc81-131c2b350843">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving A_new_hope.txt to A_new_hope.txt

# %%
uploaded = files.upload()
maskfile = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-26aeeef8-b886-4c34-9def-ecd72a1fbf7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26aeeef8-b886-4c34-9def-ecd72a1fbf7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Stormtrooper_mask.png to Stormtrooper_mask.png

# %%
with open(textfile) as fp:
  text = fp.read()
text = text.replace('HAN', 'Han')
text = text.replace('LUKE\'S', 'Luke' )

# %%
from wordcloud import STOPWORDS
stop_words = set(STOPWORDS)
stop_words.add('int')
stop_words.add('ext')
len(stop_words)
# Out:
# 192

# %%
mask = np.array(Image.open(maskfile))
wc = WordCloud(mask=mask,
               max_words = 1000,
               stopwords=stop_words,
               margin=10,
               random_state=2021)
wc.generate(text)
default_colors = wc.to_array

# %%
import random
def grey_color(word, font_size, position,
               orientation, random_state=None,
               **kwargs):
    # return 'hsl(0, 0%%, %d%%)' % random.randint(60,100)     
    # hue, saturation, lightness
    return f'hsl(0, 0%, {random.randint(60,100)}%)'

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color, random_state=2021),
           interpolation='bilinear')
plt.axis('off')
plt.show()
